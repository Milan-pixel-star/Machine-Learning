# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("F:\\New folder\\ML\\CSV files\\newplacementdata.csv")
df.head(5)
# Out:
#    cgpa  placement_exam_marks  placed
# 0  7.19                    26       1
# 1  7.46                    38       1
# 2  7.54                    40       1
# 3  6.42                     8       1
# 4  7.23                    17       0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(15,5))
plt.subplot(121)
sns.distplot(df['cgpa'])
plt.subplot(122)
sns.distplot(df['placement_exam_marks'])
plt.show()

sns.boxplot(df['placement_exam_marks'])
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2532\3977337219.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2532\3977337219.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# <Axes: >

# %%
#finding IRQ
percentile25=df['placement_exam_marks'].quantile(0.25)

percentile75=df['placement_exam_marks'].quantile(0.75)

percentile25

percentile75

IQR=percentile75-percentile25
IQR

upper_limit=percentile75+1.5*IQR
upper_limit

lower_limit=percentile25-1.5*IQR
lower_limit
# Out:
# -23.5

# %%
# Finding our outliners

df[df['placement_exam_marks']>upper_limit]

df[df['placement_exam_marks']<lower_limit]
#trimming (removeing outliner technique1)

newdf=df[df['placement_exam_marks']<upper_limit]


newdf
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                    26       1
# 1    7.46                    38       1
# 2    7.54                    40       1
# 3    6.42                     8       1
# 4    7.23                    17       0
# ..    ...                   ...     ...
# 995  8.87                    44       1
# 996  9.12                    65       1
# 997  4.89                    34       0
# 998  8.62                    46       1
# 999  4.90                    10       1
#
# [985 rows x 3 columns]

# %%
#comparision

plt.figure(figsize=(15,5))
plt.subplot(221)
sns.distplot(df['placement_exam_marks'])

plt.subplot(222)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(223)
sns.distplot(newdf['placement_exam_marks'])

plt.subplot(224)
sns.boxplot(newdf['placement_exam_marks'])

plt.show()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2532\3003858781.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2532\3003858781.py:11: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(newdf['placement_exam_marks'])

# %%
#capping( tech2)

new_df_cap=df.copy()


#min=5  max=15
#min=4,3,1
#max=20,30,50
# new min=1
#new max=50

# %%
new_df_cap['placement_exam_marks']=np.where(
    new_df_cap['placement_exam_marks']>upper_limit,
    upper_limit,
  np.where(
  new_df_cap['placement_exam_marks']< lower_limit,
  lower_limit,
  new_df_cap['placement_exam_marks']))

new_df_cap
# Out:
#      cgpa  placement_exam_marks  placed
# 0    7.19                  26.0       1
# 1    7.46                  38.0       1
# 2    7.54                  40.0       1
# 3    6.42                   8.0       1
# 4    7.23                  17.0       0
# ..    ...                   ...     ...
# 995  8.87                  44.0       1
# 996  9.12                  65.0       1
# 997  4.89                  34.0       0
# 998  8.62                  46.0       1
# 999  4.90                  10.0       1
#
# [1000 rows x 3 columns]

# %%
plt.figure(figsize=(15,8))
plt.subplot(221)
sns.distplot(df['placement_exam_marks'])

plt.subplot(222)
sns.boxplot(df['placement_exam_marks'])

plt.subplot(223)
sns.distplot(new_df_cap['placement_exam_marks'])

plt.subplot(224)
sns.boxplot(new_df_cap['placement_exam_marks'])

plt.show()
# Out:
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2532\3245562955.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['placement_exam_marks'])
# C:\Users\Owner\AppData\Local\Temp\ipykernel_2532\3245562955.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(new_df_cap['placement_exam_marks'])
